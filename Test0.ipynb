# %%
# File Path
# /content/drive/MyDrive/Colab/lattice.xlsx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
import seaborn as sns
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, r2_score
# file path = /content/drive/MyDrive/Colab/dataFile.xlsx on Google drive

# %%
#KNN
from sklearn.neighbors import KNeighborsRegressor

# %%
# data structure
columns = ['sn','Compound',
           'atomic_ra','atomic_rb','atomic_rc','atomic_rd', # Atomic radius
           'covl_ra','covl_rb', 'covl_rc', 'covl_rd', # Covalant radius
           'van_ra', 'van_rb', 'van_rc', 'van_rd', # Van der Wall radius
           'ionic_ra', 'ionic_rb', 'ionic_rc', 'ionic_rd', # Ionic radius
           'atomic_mass_a','atomic_mass_b','atomic_mass_c','atomic_mass_d', # Atomic mass
           'eNeg_a', 'eNeg_b', 'eNeg_c', 'eNeg_d', # Electronegativity
           'eAffin_a', 'eAffin_b', 'eAffin_c', 'eAffin_d', # Electron affinity
           'firstIoniz_a', 'firstIoniz_b', 'firstIoniz_c', 'firstIoniz_d', # First ionization potential
           'oxidation_a', 'oxidation_b', 'oxidation_c', 'oxidation_d', # Oxydation state
           'a','b','c', 'alpha','beta','gamma', # Lattice parameters
           'BandGap', # Band gap (some are metal too!)
           'formationE', # Formation enerrgy per atom
           'fmm', # Ferromagnetic ordering
           'spaceg', # Space Group
           'density', # Density
           'magneticO', # Magnetic moment
           'id' #Materials project id
           ]

# %%
# Mounting Google drive and reading the file (Not required if not running on colab)
#from google.colab import drive
#drive.mount('/content/drive', force_remount=True)
# Feel free to change this path as needed
data = pd.read_csv('/content/drive/MyDrive/Colab/dataFile.csv')
#columns=data.columns
data = data.iloc[3:]
print(data.head(1).dtypes)
# Out:
# sn               float64
# compound          object
# atomic_ra        float64
# atomic_rb        float64
# atomic_rc        float64
# atomic_rd        float64
# covl_ra          float64
# covl_rb          float64
# covl_rc          float64
# covl_rd          float64
# van_ra           float64
# van_rb           float64
# van_rc           float64
# van_rd           float64
# ionic_ra         float64
# ionic_rb         float64
# ionic_rc         float64
# ionic_rd         float64
# atomic_mass_a    float64
# atomic_mass_b    float64
# atomic_mass_c    float64
# atomic_mass_d    float64
# eNeg_a           float64
# eNeg_b           float64
# eNeg_c           float64
# eNeg_d           float64
# eAffin_a         float64
# eAffin_b         float64
# eAffin_c         float64
# eAffin_d         float64
# firstIoniz_a     float64
# firstIoniz_b     float64
# firstIoniz_c      object
# firstIoniz_d     float64
# oxidation_a        int64
# oxidation_b        int64
# oxidation_c        int64
# ...
